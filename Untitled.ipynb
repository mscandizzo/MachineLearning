# %%
import numpy as np
import pandas as pd
% matplotlib inline
import matplotlib.pyplot as plt

# %%
practice = pd.read_excel(r"C:/Users/maria/OneDrive - Scandizzo & Partner, LLC/SPartners/Website/711/Stores Analysis/GPforpractice.xlsx",
                         index_col='month_yr')

# %%
practice.head()
# Out:
#              Beverage  Processed Foods  Nuts//Dates      Water  \
# month_yr
# 2017-07-01  27.204278        31.152118    39.499800  75.767934
# 2017-06-01  27.051654        31.172233    38.486334  71.913257
# 2017-05-01  28.091665        29.927511    37.256315  74.173648
# 2017-04-01  27.515430        29.239367    35.606920  73.914898
# 2017-03-01  25.958791        30.613308    34.255313  72.775101
#
#             Sandwiches                      Toys                            \
# month_yr
# 2017-07-01                       42.571706                       47.838205
# 2017-06-01                       39.573010                       45.091983
# 2017-05-01                       39.292137                       80.186918
# 2017-04-01                       39.277069                       14.991945
# 2017-03-01                       39.675055                       15.946148
#
#             Nutritional/Energy Drinks       Beauty Aids                     \
# month_yr
# ...

# %%
def formulas(val1,val2):
    var3 = val1**2 + val2*2
    return var3

# %%
formulas(2,3)
# Out:
# 10

# %%
practice['test'] = formulas(practice['Beverage'],practice['Water'])

# %%
practice
# Out:
#              Beverage  Processed Foods  Nuts//Dates      Water  \
# month_yr
# 2017-07-01  27.204278        31.152118    39.499800  75.767934
# 2017-06-01  27.051654        31.172233    38.486334  71.913257
# 2017-05-01  28.091665        29.927511    37.256315  74.173648
# 2017-04-01  27.515430        29.239367    35.606920  73.914898
# 2017-03-01  25.958791        30.613308    34.255313  72.775101
# 2017-02-01  23.506416        29.075938    33.414713  70.921013
# 2017-01-01  23.765751        29.350478    36.413695  72.019619
# 2016-12-01  23.706230        29.600585    32.140527  72.555719
# 2016-11-01  23.641623        29.553746    32.323189  72.399539
# 2016-10-01  24.623392        31.547679    32.931311  72.581376
# 2016-09-01  25.312724        28.327841    31.568269  71.176933
# 2016-08-01  28.505515        36.099242    37.312125  69.729793
#
#             Sandwiches                      Toys                            \
# month_yr
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'AAA' : [1,2,1,3], 'BBB' : [1,1,2,2], 'CCC' : [2,1,3,1]})
df
# Out:
#    AAA  BBB  CCC
# 0    1    1    2
# 1    2    1    1
# 2    1    2    3
# 3    3    2    1

# %%
source_cols = df.columns # or some subset would work too.

# %%
new_cols = [str(x) + "_cat" for x in source_cols]

# %%
categories = {1 : 'Alpha', 2 : 'Beta', 3 : 'Charlie' }

# %%
df[new_cols] = df[source_cols].applymap(categories.get)

# %%
df
# Out:
#    AAA  BBB  CCC  AAA_cat BBB_cat  CCC_cat
# 0    1    1    2    Alpha   Alpha     Beta
# 1    2    1    1     Beta   Alpha    Alpha
# 2    1    2    3    Alpha    Beta  Charlie
# 3    3    2    1  Charlie    Beta    Alpha

# %%
$ jupyter --config-dir
# Out:
#   File "<ipython-input-12-12480e993813>", line 1
#     $ jupyter --config-dir
#     ^
# SyntaxError: invalid syntax

# %%
ipython locate profile
# Out:
#   File "<ipython-input-1-dcc0b1bd03f0>", line 1
#     ipython locate profile
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

lst = [1, 2,1,2,1,2]

s = pd.Series([1, 2, 3, 10, 20, 30], lst)

# %%
s
# Out:
# 1     1
# 2     2
# 1     3
# 2    10
# 1    20
# 2    30
# dtype: int64

# %%
grouped = s.groupby(level=0)

# %%
grouped.first()
# Out:
# 1    1
# 2    2
# dtype: int64

# %%
grouped.last()
# Out:
# 1    20
# 2    30
# dtype: int64

# %%
grouped.sum()
# Out:
# 1    24
# 2    42
# dtype: int64

# %%
df2 = pd.DataFrame({'X' : ['B', 'B', 'A', 'A'], 'Y' : [1, 2, 3, 4]})

# %%
df2
# Out:
#    X  Y
# 0  B  1
# 1  B  2
# 2  A  3
# 3  A  4

# %%
df2.groupby(['X']).sum()
# Out:
#    Y
# X
# A  7
# B  3

# %%
df2.groupby(['X'], sort=False).sum()
# Out:
#    Y
# X
# B  3
# A  7

# %%
df3 = pd.DataFrame({'X' : ['B', 'B', 'A', 'A','C','C'], 'Y' : [1, 2, 3, 4,5,6]})

df3.groupby(['X']).groups.keys()[:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-460154246f8c> in <module>()
#       1 df3 = pd.DataFrame({'X' : ['B', 'B', 'A', 'A','C','C'], 'Y' : [1, 2, 3, 4,5,6]})
#       2
# ----> 3 df3.groupby(['X']).groups.keys()[:2]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
xx = np.linspace(0,26,100)

# %%
xx.shape[0]
# Out:
# 100

# %%
xxx = xx.reshape(xx.shape[0],1)

# %%
type(xxx[1])
# Out:
# numpy.ndarray

# %%
type(xx[0])
# Out:
# numpy.float64

# %%
xxx[1][0]
# Out:
# 0.26262626262626265

# %%
X_train = [[6], [8], [10], [14], [18]]
y_train = [[7], [9], [13], [17.5], [18]]
X_test = [[6], [8], [11], [16]]
y_test = [[8], [12], [15], [18]]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
quadratic_featurizer = PolynomialFeatures(degree = 2)

# %%
X_train_quadratic = quadratic_featurizer.fit_transform(X_train)

# %%
X_train_quadratic
# Out:
# array([[   1.,    6.,   36.],
#        [   1.,    8.,   64.],
#        [   1.,   10.,  100.],
#        [   1.,   14.,  196.],
#        [   1.,   18.,  324.]])

# %%
X_test_quadratic = quadratic_featurizer.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor_quadratic = LinearRegression()

# %%
regressor_quadratic.fit(X_train_quadratic, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
xx_quadratic = quadratic_featurizer.transform(xxx)

# %%
plt.plot(xx, regressor_quadratic.predict(xx_quadratic));

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.plot(xx, regressor.predict(xxx))
plt.plot(xx, regressor_quadratic.predict(xx_quadratic));
